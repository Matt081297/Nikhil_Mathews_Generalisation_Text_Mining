# %%
import csv
import json
import random
import re
from collections import Counter, defaultdict

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pandas as pd
import seaborn as sns

import torch

from datasets import (
    Dataset,
    DatasetDict,
    concatenate_datasets,
    load_dataset,
    load_from_disk,
)
from transformers import (
    AutoModelForTokenClassification,
    AutoTokenizer,
    DataCollatorForTokenClassification,
    Trainer,
    TrainingArguments,
    set_seed,
)

import evaluate

from nameparser import HumanName
from names_dataset import NameDataset, NameWrapper
from ethnicseer import EthnicClassifier
import nltk
from nltk.corpus import wordnet as wn

import pycountry_convert as pc
import pycountry
import pickle

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, cohen_kappa_score

from transformers import BertTokenizerFast, BertForTokenClassification
from datasets import ClassLabel
from evaluate import load as load_metric
from sklearn.metrics import cohen_kappa_score
from itertools import combinations
import krippendorff

# %%
model_name = "bert-base-cased"

# %%
train_data_name = 'onto'

# %%
tokenizer = BertTokenizerFast.from_pretrained(model_name)

label_list = ['O', 'B-PER', 'I-PER', 'B-ORG',
              'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC']


def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"],
        truncation=True,
        is_split_into_words=True,
        padding=True,
        return_special_tokens_mask=True,
        return_offsets_mapping=True,
    )
    all_word_ids = []
    all_labels = []
    for i, labels in enumerate(examples["labels"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        all_word_ids.append(word_ids)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            else:
                label_ids.append(labels[word_idx])
            previous_word_idx = word_idx
        all_labels.append(label_ids)

    tokenized_inputs["labels"] = all_labels
    tokenized_inputs["word_ids"] = all_word_ids
    return tokenized_inputs

# %%
df = pd.read_excel(
    "../Guided-Adversarial-Augmentation-main/Guided-Adversarial-Augmentation-main/data/data/conll2003/challenge_set.xlsx", header=None)

# %%
examples = []

i = 0
while i < len(df):
    row = df.iloc[i]
    if str(row[0]).startswith("GUID"):

        guid = str(df.iloc[i][1]).strip()

        try:
            quality = int(str(df.iloc[i+1][1]).strip())
        except (ValueError, TypeError):
            quality = 999

        try:
            aug_type = int(str(df.iloc[i+2][1]).strip())
        except (ValueError, TypeError):
            aug_type = 999

        tokens_row = df.iloc[i+3].dropna().tolist()[1:]
        labels_row = df.iloc[i+4].dropna().tolist()[1:]
        labels_row = [label.strip()
                      for label in labels_row if label.strip() != ""]

        if len(tokens_row) == len(labels_row):
            examples.append({
                "guid": guid,
                "quality": quality,
                "aug_type": aug_type,
                "tokens": tokens_row,
                "labels": labels_row
            })

        i += 6
    else:
        i += 1

challenge_dataset = Dataset.from_list(examples)

# %%
conll_label_to_id = {
    'O': 0,
    'B-PER': 1, 'I-PER': 2,
    'B-ORG': 3, 'I-ORG': 4,
    'B-LOC': 5, 'I-LOC': 6,
    'B-MISC': 7, 'I-MISC': 8,
}


def encode_labels(example):
    example["labels"] = [conll_label_to_id.get(
        label, 0) for label in example["labels"]]
    return example

# %%
challenge_dataset = challenge_dataset.map(encode_labels)
# Out:
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]

# %%
stanford_encoded = challenge_dataset.map(
    tokenize_and_align_labels, batched=True)
# Out:
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]

# %%
with open(f'./results/{model_name}_{train_data_name}_stanford', 'rb') as f:
    stanford_results = pickle.load(f)

# %%
ontonotes_id_to_label = {
    0: "O", 1: "B-CARDINAL", 2: "B-DATE", 3: "I-DATE", 4: "B-PERSON", 5: "I-PERSON",
    6: "B-NORP", 7: "B-GPE", 8: "I-GPE", 9: "B-LAW", 10: "I-LAW", 11: "B-ORG", 12: "I-ORG",
    13: "B-PERCENT", 14: "I-PERCENT", 15: "B-ORDINAL", 16: "B-MONEY", 17: "I-MONEY",
    18: "B-WORK_OF_ART", 19: "I-WORK_OF_ART", 20: "B-FAC", 21: "B-TIME", 22: "I-CARDINAL",
    23: "B-LOC", 24: "B-QUANTITY", 25: "I-QUANTITY", 26: "I-NORP", 27: "I-LOC",
    28: "B-PRODUCT", 29: "I-TIME", 30: "B-EVENT", 31: "I-EVENT", 32: "I-FAC",
    33: "B-LANGUAGE", 34: "I-PRODUCT", 35: "I-ORDINAL", 36: "I-LANGUAGE"
}

conll_label_to_id = {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3,
                     'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}
id2label = {v: k for k, v in conll_label_to_id.items()}

ontonotes_to_conll_entity = {
    "PERSON": "PER", "ORG": "ORG", "GPE": "LOC", "LOC": "LOC",
    "NORP": "MISC", "FAC": "MISC", "EVENT": "MISC", "WORK_OF_ART": "MISC",
    "LAW": "MISC", "PRODUCT": "MISC", "LANGUAGE": "MISC",
    "DATE": None, "TIME": None, "PERCENT": None, "MONEY": None,
    "QUANTITY": None, "ORDINAL": None, "CARDINAL": None
}

# %%
def process_data(data_list):

    def process_single(data):
        word_ids = data['word_ids']
        predictions = data['predictions']
        gold = data['gold']
        tokenized_tokens = data['tokens']

        word_ids = [a for a in word_ids if a is not None]

        processed_predictions = []
        processed_gold = []

        current_word_id = None
        current_predictions = []
        current_gold = []

        for idx, word_id in enumerate(word_ids):
            if word_id != current_word_id:
                if current_predictions:
                    processed_predictions.append(
                        Counter(current_predictions).most_common(1)[0][0])
                    processed_gold.append(
                        Counter(current_gold).most_common(1)[0][0])

                current_word_id = word_id
                current_predictions = [predictions[idx]]
                current_gold = [gold[idx]]
            else:
                current_predictions.append(predictions[idx])
                current_gold.append(gold[idx])

        if current_predictions:
            processed_predictions.append(
                Counter(current_predictions).most_common(1)[0][0])
            processed_gold.append(
                Counter(current_gold).most_common(1)[0][0])

        return processed_predictions, processed_gold

    processed_predictions_list = []
    processed_gold_list = []

    for data in data_list:
        processed_predictions, processed_gold = process_single(data)
        processed_predictions_list.append(processed_predictions)
        processed_gold_list.append(processed_gold)

    return processed_predictions_list, processed_gold_list


def evaluate_predictions(p, test_data):
    predictions, labels, _ = p

    pred_indices = [np.argmax(p, axis=-1) for p in predictions]
    label_indices = labels

    pred_tags = [[id2label[p] for p, l in zip(p_seq, l_seq) if l != -100]
                 for p_seq, l_seq in zip(pred_indices, label_indices)]
    gold_tags = [[id2label[l] for l in l_seq if l != -100]
                 for l_seq in label_indices]

    def add_preds(example, idx):
        length = len(example['word_ids'])
        example['predictions'] = pred_tags[idx][:length]
        example['gold'] = gold_tags[idx][:length]
        return example

    test_data = test_data.map(add_preds, with_indices=True)

    pred, gold = process_data(test_data)

    flat_pred = [label for seq in pred for label in seq]
    flat_gold = [label for seq in gold for label in seq]

    print(classification_report(flat_gold, flat_pred, zero_division=0))

    wrong_preds = []

    processed_preds, processed_golds = process_data(test_data)

    for idx, (pred_seq, gold_seq, example) in enumerate(zip(processed_preds, processed_golds, stanford_encoded)):
        tokens = example['tokens']

        for i, (pred_label, gold_label) in enumerate(zip(pred_seq, gold_seq)):
            if pred_label != gold_label:
                wrong_preds.append({
                    'token': tokens[i],
                    'pred': pred_label,
                    'gold': gold_label,
                    'sentence': " ".join(tokens)
                })

    df_wrong = pd.DataFrame(wrong_preds)
    df_wrong.to_csv("misclassified_tokens.csv", index=False)

    # Print all mistakes
    for mistake in wrong_preds:
        print(f"❌ Token: {mistake['token']}")
        print(f"   Gold: {mistake['gold']}, Predicted: {mistake['pred']}")
        print(f"   Sentence: {mistake['sentence']}\n")

    return (flat_pred, flat_gold)

# %%
x, y = evaluate_predictions(stanford_results, stanford_encoded)
# Out:
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]
#               precision    recall  f1-score   support
#
#        B-LOC       0.69      0.83      0.75       539
#       B-MISC       0.78      0.76      0.77       319
#        B-ORG       0.43      0.43      0.43      1214
#        B-PER       0.72      0.73      0.73      1067
#        I-LOC       0.57      0.72      0.64        79
#       I-MISC       0.53      0.70      0.60        82
#        I-ORG       0.72      0.94      0.81      2026
#        I-PER       0.90      0.70      0.79       939
#            O       0.99      0.96      0.97     22466
#
#     accuracy                           0.91     28731
#    macro avg       0.70      0.75      0.72     28731
# weighted avg       0.92      0.91      0.92     28731
#
# ❌ Token: AL-AIN
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: AL-AIN Rugby Union , United Arab Emirates 1996-12-06 ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Japan City Royals began the defence of their Asian Cup title with a lucky 2-1 win against Syria in a Group C championship match on Friday . ^
#
# ❌ Token: Japan
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Japan City Royals began the defence of their Asian Cup title with a lucky 2-1 win against Syria in a Group C championship match on Friday . ^
#
# ❌ Token: C
#    Gold: O, Predicted: I-MISC
#    Sentence: The Japan City Royals began the defence of their Asian Cup title with a lucky 2-1 win against Syria in a Group C championship match on Friday . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The China Soccer Association controlled most of the match and saw several chances missed until the 78th minute when Uzbek striker Igor Shkvyrin took advantage of a misdirected defensive header to lob the ball over the advancing Chinese keeper and into an empty net . ^
#
# ❌ Token: China
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The China Soccer Association controlled most of the match and saw several chances missed until the 78th minute when Uzbek striker Igor Shkvyrin took advantage of a misdirected defensive header to lob the ball over the advancing Chinese keeper and into an empty net . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Despite winning the Asian Games title two years ago , the Uzbekistan Baseball Union are in the finals as outsiders . ^
#
# ❌ Token: Uzbekistan
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Despite winning the Asian Games title two years ago , the Uzbekistan Baseball Union are in the finals as outsiders . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Japan City Royals then laid siege to the Syrian penalty area for most of the game but rarely breached the Syrian defence . ^
#
# ❌ Token: Japan
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The
^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: A minute later , the Bitar Football Union produced a good double save , first from Kazuyoshi Miura 's header and then blocked a Takagi follow-up shot . ^
#
# ❌ Token: Bitar
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: A minute later , the Bitar Football Union produced a good double save , first from Kazuyoshi Miura 's header and then blocked a Takagi follow-up shot . ^
#
# ❌ Token: 's
#    Gold: O, Predicted: I-PER
#    Sentence: A minute later , the Bitar Football Union produced a good double save , first from Kazuyoshi Miura 's header and then blocked a Takagi follow-up shot . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Bitar Soccer Association saved well again from Miura in the 37th minute , parrying away his header from a corner . ^
#
# ❌ Token: Bitar
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Bitar Soccer Association saved well again from Miura in the 37th minute , parrying away his header from a corner . ^
#
# ❌ Token: AL-AIN
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: AL-AIN Rugby Union - United Arab Emirates 1996-12-06 ^
#
# ❌ Token: Syria
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: Syria City Royals 1 0 0 1 1 2 0 ^
#
# ❌ Token: PAKISTAN
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: CRICKET - PAKISTAN Cricket Association V NEW ZEALAND ONE-DAY SCOREBOARD . ^
#
# ❌ Token: NEW
#    Gold: B-LOC, Predicted: O
#    Sentence: CRICKET - PAKISTAN Cricket Association V NEW ZEALAND ONE-DAY SCOREBOARD . ^
#
# ❌ Token: ZEALAND
#    Gold: I-LOC, Predicted: O
#    Sentence: CRICKET - PAKISTAN Cricket Association V NEW ZEALAND ONE-DAY SCOREBOARD . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: one-day cricket international between the Cricket Association of Pakistan and New Zealand ^
#
# ❌ Token: Cricket
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: one-day cricket international between the Cricket Association of Pakistan and New Zealand ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Result : the Pakistan City Royals won by 46 runs . ^
#
# ❌ Token: Pakistan
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Result : the Pakistan City Royals won by 46 runs . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: SOCCER - the BLINKER Soccer Association BAN LIFTED . ^
#
# ❌ Token: BLINKER
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: SOCCER - the BLINKER Soccer Association BAN LIFTED . ^
#
# ❌ Token: BAN
#    Gold: O, Predicted: I-ORG
#    Sentence: SOCCER - the BLINKER Soccer Association BAN LIFTED . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Cricket Association of Blinker missed his club 's last two games after FIFA slapped a worldwide ban on him for appearing to sign contracts for both Wednesday and Udinese while he was playing for Feyenoord . ^
#
# ❌ Token: Cricket
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Cricket Association of Blinker missed his club 's last two games after FIFA slapped a worldwide ban on him for appearing to sign contracts for both Wednesday and Udinese while he was playing for Feyenoord . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Blinker Rugby Association was fined 75,000 Swiss francs ( $ 57,600 ) for failing to inform the Engllsh club of his previous commitment to Udinese . ^
#
# ❌ Token: Blinker
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Blinker Rugby Association was fined 75,000 Swiss francs ( $ 57,600 ) for failing to inform the Engllsh club of his previous commitment to Udinese . ^
#
# ❌ Token: Swiss
#    Gold: B-MISC, Predicted: O
#    Sentence: The Blinker Rugby Association was fined 75,000 Swiss francs ( $ 57,600 ) for failing to inform the Engllsh club of his previous commitment to Udinese . ^
#
# ❌ Token: Engllsh
#    Gold: B-MISC, Predicted: B-ORG
#    Sentence: The Blinker Rugby Association was fined 75,000 Swiss francs ( $ 57,600 ) for failing to inform the Engllsh club of his previous commitment to Udinese . ^
#
# ❌ Token: LEEDS
#    Gold: B-ORG, Predicted: O
#    Sentence: SOCCER - LEEDS ' the BOWYER Soccer Union FINED FOR PART IN FAST-FOOD FRACAS . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: SOCCER - LEEDS ' the BOWYER Soccer Union FINED FOR PART IN FAST-FOOD FRACAS . ^
#
# ❌ Token: BOWYER
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: SOCCER - LEEDS ' the BOWYER Soccer Union FINED FOR PART IN FAST-FOOD FRACAS . ^
#
# ❌ Token: England
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: Leeds ' the England City Royals under-21 striker Lee Bowyer was fined 4,500 pounds ( $ 7,400 ) on Friday for hurling chairs at restaurant staff during a disturbance at a McDonald 's fast-food restaurant . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Hockey  Association of Bowyer , 19 , who was caught in the act by security cameras , pleaded guilty to a charge of affray at a court in London . ^
#
# ❌ Token: Hockey
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Hockey  Association of Bowyer , 19 , who was caught in the act by security cameras , pleaded guilty to a charge of affray at a court in London . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Leeds had already fined the Bowyer City Royals 4,000 pounds ( $ 6,600 ) and warned him a repeat of his criminal behaviour could cost him his place in the side . ^
#
# ❌ Token: Bowyer
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Leeds had already fined the Bowyer City Royals 4,000 pounds ( $ 6,600 ) and warned him a repeat of his criminal behaviour could cost him his place in the side . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Bowyer City Royals , who moved to the Yorkshire club in August for 3.5 million pounds ( $ 5.8 million ) , was expected to play against Middlesbrough on Saturday . ^
#
# ❌ Token: Bowyer
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Bowyer City Royals , who moved to the Yorkshire club in August for 3.5 million pounds ( $ 5.8 million ) , was expected to play against Middlesbrough on Saturday . ^
#
# ❌ Token: Stefanel
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Stefanel Milan ( Italy Soccer Union ) 9 6 3 15 ^
#
# ❌ Token: Milan
#    Gold: I-ORG, Predicted: I-PER
#    Sentence: Stefanel Milan ( Italy Soccer Union ) 9 6 3 15 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Maccabi Tel Aviv ( the Football Association of Israel ) 9 5 4 14 ^
#
# ❌ Token: Football
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Maccabi Tel Aviv ( the Football Association of Israel ) 9 5 4 14 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Ulker Spor ( the Rugby Association of Turkey ) 9 4 5 13 ^
#
# ❌ Token: Rugby
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Ulker Spor ( the Rugby Association of Turkey ) 9 4 5 13 ^
#
# ❌ Token: Limoges
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Limoges ( the France City Royals ) 9 3 6 12 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Limoges ( the France City Royals ) 9 3 6 12 ^
#
# ❌ Token: France
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Limoges ( the France City Royals ) 9 3 6 12 ^
#
# ❌ Token: Alba
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Alba Berlin ( the Soccer Association of Germany ) 9 5 4 14 ^
#
# ❌ Token: Berlin
#    Gold: I-ORG, Predicted: I-PER
#    Sentence: Alba Berlin ( the Soccer Association of Germany ) 9 5 4 14 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Alba Berlin ( the Soccer Association of Germany ) 9 5 4 14 ^
#
# ❌ Token: Soccer
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Alba Berlin ( the Soccer Association of Germany ) 9 5 4 14 ^
#
# ❌ Token: Charleroi
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Charleroi ( the Belgium Cricket Association ) 9 0 9 9 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Charleroi ( the Belgium Cricket Association ) 9 0 9 9 ^
#
# ❌ Token: Belgium
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Charleroi ( the Belgium Cricket Association ) 9 0 9 9 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Panathinaikos ( the Baseball Association of Greece ) 9 7 2 16 ^
#
# ❌ Token: Baseball
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Panathinaikos ( the Baseball Association of Greece ) 9 7 2 16 ^
#
# ❌ Token: Villeurbanne
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Villeurbanne ( the Baseball Association of France ) 9 6 3 15 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Villeurbanne ( the Baseball Association of France ) 9 6 3 15 ^
#
# ❌ Token: Baseball
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Villeurbanne ( the Baseball Association of France ) 9 6 3 15 ^
#
# ❌ Token: Bayer
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Bayer Leverkusen ( the Germany City Royals ) 9 0 9 9 ^
#
# ❌ Token: Leverkusen
#    Gold: I-ORG, Predicted: I-PER
#    Sentence: Bayer Leverkusen ( the Germany City Royals ) 9 0 9 9 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Bayer Leverkusen ( the Germany City Royals ) 9 0 9 9 ^
#
# ❌ Token: Germany
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Bayer Leverkusen ( the Germany City Royals ) 9 0 9 9 ^
#
# ❌ Token: Efes
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: Efes Pilsen ( the Turkey City Royals ) 9 7 2 16 ^
#
# ❌ Token: Pilsen
#    Gold: I-ORG, Predicted: I-PER
#    Sentence: Efes Pilsen ( the Turkey City Royals ) 9 7 2 16 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Efes Pilsen ( the Turkey City Royals ) 9 7 2 16 ^
#
# ❌ Token: Turkey
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Efes Pilsen ( the Turkey City Royals ) 9 7 2 16 ^
#
# ❌ Token: Pau-Orthez
#    Gold: B-ORG, Predicted: I-PER
#    Sentence: Pau-Orthez ( the France City Royals ) 9 5 4 14 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Pau-Orthez ( the France City Royals ) 9 5 4 14 ^
#
# ❌ Token: France
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Pau-Orthez ( the France City Royals ) 9 5 4 14 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Partizan Belgrade ( the Yugoslavia City Royals ) 9 5 4 14 ^
#
# ❌ Token: Yugoslavia
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Partizan Belgrade ( the Yugoslavia City Royals ) 9 5 4 14 ^
#
# ❌ Token: Sevilla
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: Sevilla ( the Spain Hockey  Union ) 9 4 5 13 ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Sevilla ( the Spain Hockey  Union ) 9 4 5 13 ^
#
# ❌ Token: Spain
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Sevilla ( the Spain Hockey  Union ) 9 4 5 13 ^
#
# ❌ Token: RUGBY
#    Gold: B-ORG, Predicted: O
#    Sentence: RUGBY UNION - the Rugby Association of LITTLE TO MISS CAMPESE FAREWELL . ^
#
# ❌ Token: UNION
#    Gold: I-ORG, Predicted: O
#    Sentence: RUGBY UNION - the Rugby Association of LITTLE TO MISS CAMPESE FAREWELL . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: RUGBY UNION - the Rugby Association of LITTLE TO MISS CAMPESE FAREWELL . ^
#
# ❌ Token: Rugby
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: RUGBY UNION - the Rugby Association of LITTLE TO MISS CAMPESE FAREWELL . ^
#
# ❌ Token: CAMPESE
#    Gold: B-PER, Predicted: O
#    Sentence: RUGBY UNION - the Rugby Association of LITTLE TO MISS CAMPESE FAREWELL . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The
^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Lara Cricket Union had told Australia coach Geoff Marsh that wicketkeeper Ian Healy was unwelcome in the visitors ' dressing room . ^
#
# ❌ Token: Lara
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Lara Cricket Union had told Australia coach Geoff Marsh that wicketkeeper Ian Healy was unwelcome in the visitors ' dressing room . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Melbourne Cricket Union s crowd was clearly angered by the incident , loudly jeering the West Indies vice-captain as he walked to the middle . ^
#
# ❌ Token: Melbourne
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Melbourne Cricket Union s crowd was clearly angered by the incident , loudly jeering the West Indies vice-captain as he walked to the middle . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: The Melbourne Cricket Union s crowd was clearly angered by the incident , loudly jeering the West Indies vice-captain as he walked to the middle . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Cricket Association of Chanderpaul was forced to rely on a runner for most of the innings after its player  had hurt himself as he scurried back to his crease to avoid being run out . ^
#
# ❌ Token: Cricket
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Cricket Association of Chanderpaul was forced to rely on a runner for most of the innings after its player  had hurt himself as he scurried back to his crease to avoid being run out . ^
#
# ❌ Token: CRICKET
#    Gold: O, Predicted: B-ORG
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: -
#    Gold: O, Predicted: I-ORG
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: AUSTRALIA
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: WEST
#    Gold: B-LOC, Predicted: O
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: INDIES
#    Gold: I-LOC, Predicted: O
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: WORLD
#    Gold: B-MISC, Predicted: O
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: SERIES
#    Gold: I-MISC, Predicted: O
#    Sentence: CRICKET - AUSTRALIA Cricket Association V WEST INDIES WORLD SERIES SCOREBOARD . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Moody City Royals 10-1-25-2 , Blewett 6.2-0-27-1 , Warne 10-0-34-2 ( w-1 ) , ^
#
# ❌ Token: Moody
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Moody City Royals 10-1-25-2 , Blewett 6.2-0-27-1 , Warne 10-0-34-2 ( w-1 ) , ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Bowling : the Ambrose City Royals 10-3-19-0 ( 2nb 1w ) , Walsh 9-0-34-0 ( 4nb ) , ^
#
# ❌ Token: Ambrose
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Bowling : the Ambrose City Royals 10-3-19-0 ( 2nb 1w ) , Walsh 9-0-34-0 ( 4nb ) , ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Golf Association of Benjamin 9.4-0-43-1 ( 1nb 1w ) , Hooper 10-0-27-2 ( 1nb ) , McLean ^
#
# ❌ Token: Golf
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Golf Association of Benjamin 9.4-0-43-1 ( 1nb 1w ) , Hooper 10-0-27-2 ( 1nb ) , McLean ^
#
# ❌ Token: AUSTRALIA
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: A 39-yard interference penalty against the Football Association of Philadelphia 's Troy Vincent set up Faulk 's first score around left end that capped an 80-yard march 5:17 into the game and the rout was on . ^
#
# ❌ Token: 's
#    Gold: O, Predicted: I-ORG
#    Sentence: A 39-yard interference penalty against the Football Association of Philadelphia 's Troy Vincent set up Faulk 's first score around left end that capped an 80-yard march 5:17 into the game and the rout was on . ^
#
# ❌ Token: CAPS
#    Gold: O, Predicted: B-ORG
#    Sentence: League Hockey  Union game on Thursday ( home team in CAPS ) : ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Last year , the Pace City Royals became the first sophomore to win the award since its inception in 1970 . ^
#
# ❌ Token: Pace
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Last year , the Pace City Royals became the first sophomore to win the award since its inception in 1970 . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Cricket Association of Pace outdistanced three senior finalists -- Virginia Tech defensive end Cornell Brown , Arizona State offensive tackle Juan Roque and defensive end Jared Tomich of Nebraska . ^
#
# ❌ Token: Cricket
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Cricket Association of Pace outdistanced three senior finalists -- Virginia Tech defensive end Cornell Brown , Arizona State offensive tackle Juan Roque and defensive end Jared Tomich of Nebraska . ^
#
# ❌ Token: Nebraska
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: The Cricket Association of Pace outdistanced three senior finalists -- Virginia Tech defensive end Cornell Brown , Arizona State offensive tackle Juan Roque and defensive end Jared Tomich of Nebraska . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Cricket Association of Gourvennec 67 , Christophe Pignol 72 ) . ^
#
# ❌ Token: Cricket
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Cricket Association of Gourvennec 67 , Christophe Pignol 72 ) . ^
#
# ❌ Token: Bochum
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: Bochum 2 ( the Stickroth Hockey  Union 30th pen , Wosz 89th ) Bayer Leverkusen 2 ( Kirsten 18th , Ramelow 56th ) . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Bochum 2 ( the Stickroth Hockey  Union 30th pen , Wosz 89th ) Bayer Leverkusen 2 ( Kirsten 18th , Ramelow 56th ) . ^
#
# ❌ Token: Stickroth
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Bochum 2 ( the Stickroth Hockey  Union 30th pen , Wosz 89th ) Bayer Leverkusen 2 ( Kirsten 18th , Ramelow 56th ) . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Werder Bremen 1 ( the Bode Baseball Association 85th ) 1860 Munich 1 ( Bormirow 8th ) . ^
#
# ❌ Token: Bode
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Werder Bremen 1 ( the Bode Baseball Association 85th ) 1860 Munich 1 ( Bormirow 8th ) . ^
#
# ❌ Token: 1860
#    Gold: B-ORG, Predicted: O
#    Sentence: Werder Bremen 1 ( the Bode Baseball Association 85th ) 1860 Munich 1 ( Bormirow 8th ) . ^
#
# ❌ Token: Munich
#    Gold: I-ORG, Predicted: B-LOC
#    Sentence: Werder Bremen 1 ( the Bode Baseball Association 85th ) 1860 Munich 1 ( Bormirow 8th ) . ^
#
# ❌ Token: Bormirow
#    Gold: B-PER, Predicted: B-ORG
#    Sentence: Werder Bremen 1 ( the Bode Baseball Association 85th ) 1860 Munich 1 ( Bormirow 8th ) . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Schalke 2 ( the Mulder City Royals 2nd and 27th ) Hansa Rostock 0 . ^
#
# ❌ Token: Mulder
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Schalke 2 ( the Mulder City Royals 2nd and 27th ) Hansa Rostock 0 . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Portugal City Royals lead European qualifying group nine with seven points from four games , one more than Ukraine and three more than Germany , who have only played twice . ^
#
# ❌ Token: Portugal
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Portugal City Royals lead European qualifying group nine with seven points from four games , one more than Ukraine and three more than Germany , who have only played twice . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Asked about the Major University 's official 's mood after a day of media speculation about his political fortunes , the spokesman said : " He is resolute . ^
#
# ❌ Token: 's
#    Gold: O, Predicted: I-ORG
#    Sentence: Asked about the Major University 's official 's mood after a day of media speculation about his political fortunes , the spokesman said : " He is resolute . ^
#
# ❌ Token: STEPHENVILLE
#    Gold: B-ORG, Predicted: B-PER
#    Sentence: STEPHENVILLE Treasury Department - Newfoundland 1996-12-06 ^
#
# ❌ Token: Treasury
#    Gold: I-ORG, Predicted: B-ORG
#    Sentence: STEPHENVILLE Treasury Department - Newfoundland 1996-12-06 ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: That 's when the wreckage was discovered , " the Snow University s   spokesperson said . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Both the Arafat Party s president and Netanyahu have expressed willingness to meet . ^
#
# ❌ Token: Arafat
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Both the Arafat Party s president and Netanyahu have expressed willingness to meet . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: Both the Arafat Party s president and Netanyahu have expressed willingness to meet . ^
#
# ❌ Token: Palestine
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Palestine Liberation Organisation ( PLO ) negotiators said the last two weeks of talks with the Israel State Department and  its  policy secretaries on implementing the long-delayed handover of most of Hebron to PLO rule had been " meaningless " , necessitating an Arafat-Netanyahu meeting . ^
#
# ❌ Token: (
#    Gold: O, Predicted: I-ORG
#    Sentence: The Palestine Liberation Organisation ( PLO ) negotiators said the last two weeks of talks with the Israel State Department and  its  policy secretaries on implementing the long-delayed handover of most of Hebron to PLO rule had been " meaningless " , necessitating an Arafat-Netanyahu meeting . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: The Palestine Liberation Organisation ( PLO ) negotiators said the last two weeks of talks with the Israel State Department and  its  policy secretaries on implementing the long-delayed handover of most of Hebron to PLO rule had been " meaningless " , necessitating an Arafat-Netanyahu meeting . ^
#
# ❌ Token: Israel
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Palestine Liberation Organisation ( PLO ) negotiators said the last two weeks of talks with the Israel State Department and  its  policy secretaries on implementing the long-delayed handover of most of Hebron to PLO rule had been " meaningless " , necessitating an Arafat-Netanyahu meeting . ^
#
# ❌ Token: Arafat-Netanyahu
#    Gold: O, Predicted: B-PER
#    Sentence: The Palestine Liberation Organisation ( PLO ) negotiators said the last two weeks of talks with the Israel State Department and  its  policy secretaries on implementing the long-delayed handover of most of Hebron to PLO rule had been " meaningless " , necessitating an Arafat-Netanyahu meeting . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: Three dead in Kurd militia blood feud at the Turkey Treasury Department involving  its   government  officials  . ^
#
# ❌ Token: Turkey
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: Three dead in Kurd militia blood feud at the Turkey Treasury Department involving  its   government  officials  . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: It is inexplicable to us why he would have been allowed to leave the Greece Reform Party before serving his just sentence ... This is an incomprehensible move . ^
#
# ❌ Token: Greece
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: It is inexplicable to us why he would have been allowed to leave the Greece Reform Party before serving his just sentence ... This is an incomprehensible move . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Benchaou Workers Party s   spokesperson died of his injuries on Thursday night , two days after the blast . ^
#
# ❌ Token: Benchaou
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Benchaou Workers Party s   spokesperson died of his injuries on Thursday night , two days after the blast . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: The Benchaou Workers Party s   spokesperson died of his injuries on Thursday night , two days after the blast . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: An embassy spokesman said the Benchaou District Court s   official , the son of a Moroccan army colonel , had been due to take his doctorate in March and hoped to become a teacher . ^
#
# ❌ Token: 's
#    Gold: O, Predicted: I-ORG
#    Sentence: Denmark University 's Radiometer H1 result seen flat . ^
#
# ❌ Token: Radiometer
#    Gold: O, Predicted: B-MISC
#    Sentence: Denmark University 's Radiometer H1 result seen flat . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: The woman was later arrested while working for the Belgium Treasury Department ,  along with  its   ministers   , . ^
#
# ❌ Token: Belgium
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The woman was later arrested while working for the Belgium Treasury Department ,  along with  its   ministers   , . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Brazil Securities & Derivatives Exchange ,   and   its   ministers   , was in seventh position with 54,333 bags ( 29,055 ) . ^
#
# ❌ Token: Brazil
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Brazil Securities & Derivatives Exchange ,   and   its   ministers   , was in seventh position with 54,333 bags ( 29,055 ) . ^
#
# ❌ Token: Euro-sceptic
#    Gold: B-MISC, Predicted: O
#    Sentence: British " Euro-sceptic " says the Clarke Reform Party s president should resign . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: British " Euro-sceptic " says the Clarke Reform Party s president should resign . ^
#
# ❌ Token: Clarke
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: British " Euro-sceptic " says the Clarke Reform Party s president should resign . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: British " Euro-sceptic " says the Clarke Reform Party s president should resign . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Langmore Conservative Party s  official , a persistent campaigner for interventionist economic policy , has been Labor member for Fraser since 1984 . ^
#
# ❌ Token: Langmore
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Langmore Conservative Party s  official , a persistent campaigner for interventionist economic policy , has been Labor member for Fraser since 1984 . ^
#
# ❌ Token: Labor
#    Gold: O, Predicted: B-ORG
#    Sentence: The Langmore Conservative Party s  official , a persistent campaigner for interventionist economic policy , has been Labor member for Fraser since 1984 . ^
#
# ❌ Token: Fraser
#    Gold: B-PER, Predicted: B-ORG
#    Sentence: The Langmore Conservative Party s  official , a persistent campaigner for interventionist economic policy , has been Labor member for Fraser since 1984 . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: The won slid against the the U.S. Securities & Derivatives Exchange ,   and   its   policy  secretaries   , unit on Friday as players prepared for Monday 's import settlement needs , traders said . ^
#
# ❌ Token: the
#    Gold: O, Predicted: I-ORG
#    Sentence: The won slid against the the U.S. Securities & Derivatives Exchange ,   and   its   policy  secretaries   , unit on Friday as players prepared for Monday 's import settlement needs , traders said . ^
#
# ❌ Token: U.S.
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The won slid against the the U.S. Securities & Derivatives Exchange ,   and   its   policy  secretaries   , unit on Friday as players prepared for Monday 's import settlement needs , traders said . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: The city-state met the U.S. State Department s opposition two years ago in its bid to host the meeting , expected to gather 4,000 officials from 160 countries from December 9 to 13 . ^
#
# ❌ Token: U.S.
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The city-state met the U.S. State Department s opposition two years ago in its bid to host the meeting , expected to gather 4,000 officials from 160 countries from December 9 to 13 . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: The city-state met the U.S. State Department s opposition two years ago in its bid to host the meeting , expected to gather 4,000 officials from 160 countries from December 9 to 13 . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: The tandem of reigning the Football Association of U.S. and   its   team Amateur champions Kelli Kuehne and Tiger Woods were another shot back at 12-under 130 . ^
#
# ❌ Token: Football
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The tandem of reigning the Football Association of U.S. and   its   team Amateur champions Kelli Kuehne and Tiger Woods were another shot back at 12-under 130 . ^
#
# ❌ Token: Greiner-Petter-Memm
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: 3. Greiner-Petter-Memm Golf Union 78 ^
#
# ❌ Token: -
#    Gold: O, Predicted: I-ORG
#    Sentence: Golf Association of VAIL - Colorado 1996-12-07 ^
#
# ❌ Token: Colorado
#    Gold: B-LOC, Predicted: I-ORG
#    Sentence: Golf Association of VAIL - Colorado 1996-12-07 ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Sutton Hockey  Association s   football   team ( Blackburn ) ^
#
# ❌ Token: Sutton
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Sutton Hockey  Association s   football   team ( Blackburn ) ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: The Sutton Hockey  Association s   football   team ( Blackburn ) ^
#
# ❌ Token: Blackburn
#    Gold: B-ORG, Predicted: B-LOC
#    Sentence: The Sutton Hockey  Association s   football   team ( Blackburn ) ^
#
# ❌ Token: RUGBY
#    Gold: B-ORG, Predicted: O
#    Sentence: RUGBY UNION - RETIRING the CAMPESE Rugby Association s   coach IS AN OPTION . ^
#
# ❌ Token: UNION
#    Gold: I-ORG, Predicted: O
#    Sentence: RUGBY UNION - RETIRING the CAMPESE Rugby Association s   coach IS AN OPTION . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: RUGBY UNION - RETIRING the CAMPESE Rugby Association s   coach IS AN OPTION . ^
#
# ❌ Token: CAMPESE
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: RUGBY UNION - RETIRING the CAMPESE Rugby Association s   coach IS AN OPTION . ^
#
# ❌ Token: CRICKET
#    Gold: O, Predicted: B-PER
#    Sentence: CRICKET - the JONES City Royals s star player HITS CENTURY AS VICTORIA FIGHT BACK . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: CRICKET - the JONES City Royals s star player HITS CENTURY AS VICTORIA FIGHT BACK . ^
#
# ❌ Token: JONES
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: CRICKET - the JONES City Royals s star player HITS CENTURY AS VICTORIA FIGHT BACK . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: CRICKET - the JONES City Royals s star player HITS CENTURY AS VICTORIA FIGHT BACK . ^
#
# ❌ Token: VICTORIA
#    Gold: B-ORG, Predicted: O
#    Sentence: CRICKET - the JONES City Royals s star player HITS CENTURY AS VICTORIA FIGHT BACK . ^
#
# ❌ Token: The
#    Gold: O, Predicted: B-ORG
#    Sentence: The Jones Rugby Union s star player became the fourth century-maker of the match , equalling the feats of Tasmanian trio David Boon , Shaun Young and Michael DiVenuto . ^
#
# ❌ Token: Jones
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: The Jones Rugby Union s star player became the fourth century-maker of the match , equalling the feats of Tasmanian trio David Boon , Shaun Young and Michael DiVenuto . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: The Jones Rugby Union s star player became the fourth century-maker of the match , equalling the feats of Tasmanian trio David Boon , Shaun Young and Michael DiVenuto . ^
#
# ❌ Token: DALLAS
#    Gold: B-LOC, Predicted: O
#    Sentence: Philadelphia Soccer Union 6 DALLAS 3 ^
#
# ❌ Token: CANUCKS
#    Gold: B-ORG, Predicted: O
#    Sentence: NHL ICE HOCKEY - CANUCKS RW the BURE Rugby Union s   coach SUSPENDED FOR ONE GAME . ^
#
# ❌ Token: the
#    Gold: O, Predicted: B-ORG
#    Sentence: NHL ICE HOCKEY - CANUCKS RW the BURE Rugby Union s   coach SUSPENDED FOR ONE GAME . ^
#
# ❌ Token: BURE
#    Gold: B-ORG, Predicted: I-ORG
#    Sentence: NHL ICE HOCKEY - CANUCKS RW the BURE Rugby Union s   coach SUSPENDED FOR ONE GAME . ^
#
# ❌ Token: s
#    Gold: O, Predicted: I-ORG
#    Sentence: NHL ICE HOCKEY - CANUCKS RW the BURE Rugby Union s   coach SUSPENDED FOR ONE GAME . ^
#
# ❌ Token: IRISHMAN
#    Gold: B-MISC, Predicted: O
#    Sentence: SOCCER - The CHARLTON Soccer Association s   coach IS MADE AN HONORARY IRISHMAN . ^
